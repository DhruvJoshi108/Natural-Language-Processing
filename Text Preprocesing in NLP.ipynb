# %%
import pandas as pd
import nltk

from nltk.corpus import stopwords, wordnet
from nltk.stem import SnowballStemmer, WordNetLemmatizer
from nltk.tokenize import word_tokenize
from nltk import pos_tag

# %%
# Load dataset
df = pd.read_csv("D:\\Data Set for Project\\df_file.csv")

stop_words = set(stopwords.words("english"))
stemmer = SnowballStemmer('english')
lemmatizer = WordNetLemmatizer()

# %%
def map_pos(tag):
    if tag.startswith("J"):
        return wordnet.ADJ
    if tag.startswith("V"):
        return wordnet.VERB
    if tag.startswith("R"):
        return wordnet.ADV
    return wordnet.NOUN

# %%
def preprocess(text):
    tokens = word_tokenize(text.lower())
    tokens = [w for w in tokens if w.isalpha()]
    tokens = [w for w in tokens if w not in stop_words]

    pos_tags = pos_tag(tokens)

    stemmed = [stemmer.stem(w) for w in tokens]
    lemmatized = [
        lemmatizer.lemmatize(w, map_pos(tag))
        for w, tag in pos_tags
    ]

    return tokens, stemmed, lemmatized

# %%
df["tokens"], df["stemmed"], df["lemmatized"] = zip(*df["Text"].apply(preprocess))

# %%
df[["tokens", "stemmed", "lemmatized"]].head()
# Out:
#                                               tokens  \
# 0  [budget, set, scene, election, gordon, brown, ...
# 1  [army, chiefs, regiments, decision, military, ...
# 2  [howard, denies, split, id, cards, michael, ho...
# 3  [observers, monitor, uk, election, ministers, ...
# 4  [kilroy, names, election, seat, target, show, ...
#
#                                              stemmed  \
# 0  [budget, set, scene, elect, gordon, brown, see...
# 1  [armi, chief, regiment, decis, militari, chief...
# 2  [howard, deni, split, id, card, michael, howar...
# 3  [observ, monitor, uk, elect, minist, invit, in...
# 4  [kilroy, name, elect, seat, target, show, host...
#
#                                           lemmatized
# 0  [budget, set, scene, election, gordon, brown, ...
# 1  [army, chief, regiment, decision, military, ch...
# 2  [howard, deny, split, id, card, michael, howar...
# 3  [observer, monitor, uk, election, minister, in...
# 4  [kilroy, name, election, seat, target, show, h...
