# %% [markdown]
# ## Rule Based Matching

# %%
import spacy

# %%
nlp = spacy.load('en_core_web_sm')

# %%
from spacy.matcher import  Matcher
matcher= Matcher(nlp.vocab)

# %%
pattern1 = [{'LOWER':'solarpower'}]
pattern2 = [{'LOWER':'solar'} , {'LOWER':'power'}]
pattern3 = [{'LOWER':'solar'}  , {'IS_PUNCT':True} , {'LOWER':'power'}]
matcher.add('SolarPower', [pattern1, pattern2, pattern3])

# %%
doc = nlp("The Solar Power industry is growing fast. solarpower is an efficient source. solar-power systems are trending.")

# %%
found_matches = matcher(doc)
print(found_matches)
# Out:
# [(8656102463236116519, 1, 3), (8656102463236116519, 8, 9), (8656102463236116519, 14, 17)]

# %%
for match_id, start, end in found_matches:
    strind_id = nlp.vocab.strings[match_id]
    span = doc[start:end]
    print(match_id, span.text)
# Out:
# 8656102463236116519 Solar Power
# 8656102463236116519 solarpower
# 8656102463236116519 solar-power

# %%
pattern1 = pattern1 = [{'LOWER':'solarpower'}]

pattern3 = [{'LOWER':'solar'}  , {'IS_PUNCT':True , 'OP':'*'} , {'LOWER':'power'}]
matcher.add('SolarPower', [pattern1 , pattern2])

# %% [markdown]
# Phrase matcher
