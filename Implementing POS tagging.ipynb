# %%
import pdfplumber

def extract_text_from_pdf(pdf_path):
    text = []
    with pdfplumber.open(pdf_path) as pdf:
        for page in pdf.pages:
            page_text = page.extract_text()
            if page_text:
                text.append(page_text)
    return "\n".join(text)

pdf_text = extract_text_from_pdf("C:\\Users\\dhruv joshi\\Downloads\\SP_Uttarakhand.pdf")

print(pdf_text[:1000])
# Out:
# State Profile of Uttarakhand
# Uttarakhand was formed on the 9th November 2000 as the 27th State of India, when it was
# carved out of northern Uttar Pradesh. Located at the foothills of the Himalayan mountain ranges,
# it is largely a hilly State, having international boundaries with China (Tibet) in the north and
# Nepal in the east. On its north-west lies Himachal Pradesh, while on the south is Uttar Pradesh. It
# is rich in natural resources especially water and forests with many glaciers, rivers, dense forests
# and snow-clad mountain peaks. Char-dhams, the four most sacred and revered Hindu temples of
# Badrinath,Kedarnath, Gangotri and Yamunotri are nestled in the mighty mountains. It’s truly
# God’s Land (Dev Bhoomi). Dehradun is the Capital of Uttarakhand. It is one of the most
# beautiful resort in the submountain tracts of India, known for its scenic surroundings. The town
# lies in the Dun Valley, on the watershed of the Ganga and Yamuna rivers.
# It is blessed with a rare bio-diversity, inter-a

# %% [markdown]
# **Step 1: PDF Text Extraction (pdfplumber)**
#
# pdfplumber extracts text using layout aware parsing.
#
# What it does:
#
# - Reads embedded text objects
#
# - Preserves reading order better than PyPDF2
#
# - Exposes line breaks and layout artifacts

# %%
import re

def clean_text(text):
    text = re.sub(r'-\n', '', text)          # fix hyphenation
    text = re.sub(r'\n+', ' ', text)         # normalize line breaks
    text = re.sub(r'\s+', ' ', text)         # normalize spaces
    return text.strip()

cleaned_text = clean_text(pdf_text)

# %% [markdown]
# **Step 2: Text Cleaning**
#
# You applied regex cleanup to the raw text.
#
# Purpose:
#
# - Remove hyphenation across lines
#
# - Collapse excessive newlines
#
# - Normalize spacing

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
doc = nlp(cleaned_text)

# %% [markdown]
# **Step 3: Load spaCy Language Model**
#
# I loaded en_core_web_sm.
#
# This provides:
#
# - Tokenizer
#
# - Sentence boundary detection
#
# - POS tagger
#
# - Dependency parser

# %%
for token in doc[:100]:  # limit output or you will drown in it
    print(token.text, token.pos_, token.tag_)
# Out:
# State PROPN NNP
# Profile PROPN NNP
# of ADP IN
# Uttarakhand PROPN NNP
# Uttarakhand PROPN NNP
# was AUX VBD
# formed VERB VBN
# on ADP IN
# the DET DT
# 9th ADJ JJ
# November PROPN NNP
# 2000 NUM CD
# as ADP IN
# the DET DT
# 27th ADJ JJ
# State PROPN NNP
# of ADP IN
# India PROPN NNP
# , PUNCT ,
# when SCONJ WRB
# it PRON PRP
# was AUX VBD
# carved VERB VBN
# out ADP IN
# of ADP IN
# northern ADJ JJ
# Uttar PROPN NNP
# Pradesh PROPN NNP
# . PUNCT .
# Located VERB VBN
# at ADP IN
# the DET DT
# foothills NOUN NNS
# of ADP IN
# the DET DT
# Himalayan ADJ JJ
# mountain NOUN NN
# ranges AUX VBZ
# , PUNCT ,
# it PRON PRP
# is AUX VBZ
# largely ADV RB
# a DET DT
# hilly ADJ JJ
# State NOUN NN
# , PUNCT ,
# having VERB VBG
# international ADJ JJ
# boundaries NOUN NNS
# with ADP IN
# China PROPN NNP
# ( PUNCT -LRB-
# Tibet PROPN NNP
# ) PUNCT -RRB-
# in ADP IN
# the DET DT
# north NOUN NN
# and CCONJ CC
# Nepal PROPN NNP
# in ADP IN
# the DET DT
# east NOUN NN
# . PUNCT .
# On ADP IN
# its PRON PRP$
# north NOUN NN
# - PUNCT HYPH
# west NOUN NN
# lies VERB VBZ
# Himachal PROPN NNP
# Pradesh PROPN NNP
# , PUNCT ,
# while SCONJ IN
# on ADP IN
# the DET DT
# south NOUN NN
# is AUX VBZ
# Uttar PROPN NNP
# Pradesh PROPN NNP
# . PUNCT .
# It PRON PRP
# is AUX VBZ
# rich ADJ JJ
# in ADP IN
# natural ADJ JJ
# resources NOUN NNS
# especially ADV RB
# water NOUN NN
# and CCONJ CC
# forests NOUN NNS
# with ADP IN
# many ADJ JJ
# glaciers NOUN NNS
# , PUNCT ,
# rivers NOUN NNS
# , PUNCT ,
# dense ADJ JJ
# forests NOUN NNS
# and CCONJ CC
# snow NOUN NN

# %% [markdown]
# **Step 4: NLP Processing**
#
# I passed cleaned text to spaCy.
#
# spaCy then:
#
# - Segments sentences statistically
#
# - Assigns POS tags to tokens
#
# - Builds dependency trees per sentence

# %%
for token in doc[:100]:
    print(
        token.text,
        "HEAD:", token.head.text,
        "DEP:", token.dep_
    )
# Out:
# State HEAD: Profile DEP: compound
# Profile HEAD: formed DEP: nsubjpass
# of HEAD: Profile DEP: prep
# Uttarakhand HEAD: Uttarakhand DEP: compound
# Uttarakhand HEAD: of DEP: pobj
# was HEAD: formed DEP: auxpass
# formed HEAD: formed DEP: ROOT
# on HEAD: formed DEP: prep
# the HEAD: November DEP: det
# 9th HEAD: November DEP: amod
# November HEAD: on DEP: pobj
# 2000 HEAD: November DEP: nummod
# as HEAD: formed DEP: prep
# the HEAD: State DEP: det
# 27th HEAD: State DEP: amod
# State HEAD: as DEP: pobj
# of HEAD: State DEP: prep
# India HEAD: of DEP: pobj
# , HEAD: State DEP: punct
# when HEAD: carved DEP: advmod
# it HEAD: carved DEP: nsubjpass
# was HEAD: carved DEP: auxpass
# carved HEAD: State DEP: relcl
# out HEAD: carved DEP: prep
# of HEAD: out DEP: prep
# northern HEAD: Pradesh DEP: amod
# Uttar HEAD: Pradesh DEP: compound
# Pradesh HEAD: of DEP: pobj
# . HEAD: formed DEP: punct
# Located HEAD: is DEP: advcl
# at HEAD: Located DEP: prep
# the HEAD: foothills DEP: det
# foothills HEAD: at DEP: pobj
# of HEAD: foothills DEP: prep
# the HEAD: mountain DEP: det
# Himalayan HEAD: mountain DEP: amod
# mountain HEAD: of DEP: pobj
# ranges HEAD: Located DEP: auxpass
# , HEAD: is DEP: punct
# it HEAD: is DEP: nsubj
# is HEAD: is DEP: ROOT
# largely HEAD: is DEP: advmod
# a HEAD: State DEP: det
# hilly HEAD: State DEP: amod
# State HEAD: is DEP: attr
# , HEAD: is DEP: punct
# having HEAD: is DEP: advcl
# international HEAD: boundaries DEP: amod
# boundaries HEAD: having DEP: dobj
# with HEAD: boundaries DEP: prep
# China HEAD: with DEP: pobj
# ( HEAD: China DEP: punct
# Tibet HEAD: China DEP: appos
# ) HEAD: China DEP: punct
# in HEAD: boundaries DEP: prep
# the HEAD: north DEP: det
# north HEAD: in DEP: pobj
# and HEAD: north DEP: cc
# Nepal HEAD: north DEP: conj
# in HEAD: having DEP: prep
# the HEAD: east DEP: det
# east HEAD: in DEP: pobj
# . HEAD: is DEP: punct
# On HEAD: lies DEP: prep
# its HEAD: west DEP: poss
# north HEAD: west DEP: compound
# - HEAD: west DEP: punct
# west HEAD: On DEP: pobj
# lies HEAD: lies DEP: ROOT
# Himachal HEAD: Pradesh DEP: compound
# Pradesh HEAD: lies DEP: nsubj
# , HEAD: lies DEP: punct
# while HEAD: is DEP: mark
# on HEAD: is DEP: prep
# the HEAD: south DEP: det
# south HEAD: on DEP: pobj
# is HEAD: lies DEP: advcl
# Uttar HEAD: Pradesh DEP: compound
# Pradesh HEAD: is DEP: attr
# . HEAD: lies DEP: punct
# It HEAD: is DEP: nsubj
# is HEAD: is DEP: ROOT
# rich HEAD: is DEP: acomp
# in HEAD: rich DEP: prep
# natural HEAD: resources DEP: amod
# resources HEAD: in DEP: pobj
# especially HEAD: water DEP: advmod
# water HEAD: It DEP: appos
# and HEAD: water DEP: cc
# forests HEAD: water DEP: conj
# with HEAD: forests DEP: prep
# many HEAD: glaciers DEP: amod
# glaciers HEAD: with DEP: pobj
# , HEAD: glaciers DEP: punct
# rivers HEAD: glaciers DEP: conj
# , HEAD: rivers DEP: punct
# dense HEAD: forests DEP: amod
# forests HEAD: rivers DEP: conj
# and HEAD: forests DEP: cc
# snow HEAD: clad DEP: npadvmod

# %% [markdown]
# **Step 5: POS Tagging**
#
# I extracted:
#
# - Token text
#
# - Coarse POS tag
#
# - Fine grained POS tag
#
# Use case:
#
# - Grammatical labeling
#
# - Feature extraction

# %%
for sent in doc.sents:
    print("SENTENCE:", sent.text)
    for token in sent:
        print(
            token.text,
            token.pos_,
            token.dep_,
            "→",
            token.head.text
        )
    print()
# Out:
# SENTENCE: State Profile of Uttarakhand Uttarakhand was formed on the 9th November 2000 as the 27th State of India, when it was carved out of northern Uttar Pradesh.
# State PROPN compound → Profile
# Profile PROPN nsubjpass → formed
# of ADP prep → Profile
# Uttarakhand PROPN compound → Uttarakhand
# Uttarakhand PROPN pobj → of
# was AUX auxpass → formed
# formed VERB ROOT → formed
# on ADP prep → formed
# the DET det → November
# 9th ADJ amod → November
# November PROPN pobj → on
# 2000 NUM nummod → November
# as ADP prep → formed
# the DET det → State
# 27th ADJ amod → State
# State PROPN pobj → as
# of ADP prep → State
# India PROPN pobj → of
# , PUNCT punct → State
# when SCONJ advmod → carved
# it PRON nsubjpass → carved
# was AUX auxpass → carved
# carved VERB relcl → State
# out ADP prep → carved
# of ADP prep → out
# northern ADJ amod → Pradesh
# Uttar PROPN compound → Pradesh
# Pradesh PROPN pobj → of
# . PUNCT punct → formed
#
# SENTENCE: Located at the foothills of the Himalayan mountain ranges, it is largely a hilly State, having international boundaries with China (Tibet) in the north and Nepal in the east.
# Located VERB advcl → is
# at ADP prep → Located
# the DET det → foothills
# foothills NOUN pobj → at
# of ADP prep → foothills
# the DET det → mountain
# Himalayan ADJ amod → mountain
# mountain NOUN pobj → of
# ranges AUX auxpass → Located
# , PUNCT punct → is
# it PRON nsubj → is
# is AUX ROOT → is
# largely ADV advmod → is
# a DET det → State
# hilly ADJ amod → State
# State NOUN attr → is
# , PUNCT punct → is
# having VERB advcl → is
# international ADJ amod → boundaries
# boundaries NOUN dobj → having
# with ADP prep → boundaries
# China PROPN pobj → with
# ( PUNCT punct → China
# Tibet PROPN appos → China
# ) PUNCT punct → China
# in ADP prep → boundaries
# the DET det → north
# north NOUN pobj → in
# and CCONJ cc → north
# Nepal PROPN conj → north
# in ADP prep → having
# the DET det → east
# east NOUN pobj → in
# . PUNCT punct → is
#
# SENTENCE: On its north-west lies Himachal Pradesh, while on the south is Uttar Pradesh.
# On ADP prep → lies
# its PRON poss → west
# north NOUN compound → west
# - PUNCT punct → west
# west NOUN pobj → On
# lies VERB ROOT → lies
# Himachal PROPN compound → Pradesh
# Pradesh PROPN nsubj → lies
# , PUNCT punct → lies
# while SCONJ mark → is
# on ADP prep → is
# the DET det → south
# south NOUN pobj → on
# is AUX advcl → lies
# Uttar PROPN compound → Pradesh
# Pradesh PROPN attr → is
# . PUNCT punct → lies
#
# SENTENCE: It is rich in natural resources especially water and forests with many glaciers, rivers, dense forests and snow-clad mountain peaks.
# It PRON nsubj → is
# is AUX ROOT → is
# rich ADJ acomp → is
# in ADP prep → rich
# natural ADJ amod → resources
# resources NOUN pobj → in
# especially ADV advmod → water
# water NOUN appos → It
# and CCONJ cc → water
# forests NOUN conj → water
# with ADP prep → forests
# many ADJ amod → glaciers
# glaciers NOUN pobj → with
# , PUNCT punct → glaciers
# rivers NOUN conj → glaciers
# , PUNCT punct → rivers
# dense ADJ amod → forests
# forests NOUN conj → rivers
# and CCONJ cc → forests
# snow NOUN npadvmod → clad
# - PUNCT punct → clad
# clad VERB amod → peaks
# mountain NOUN compound → peaks
# peaks NOUN conj → forests
# . PUNCT punct → is
#
# SENTENCE: Char-dhams, the four most sacred and revered Hindu temples of Badrinath,Kedarnath, Gangotri and Yamunotri are nestled in the mighty mountains.
# Char ADJ compound → dhams
# - PUNCT punct → dhams
# dhams NOUN nsubjpass → nestled
# , PUNCT punct → dhams
# the DET det → four
# four NUM nsubjpass → nestled
# most ADV advmod → sacred
# sacred ADJ amod → four
# and CCONJ cc → sacred
# revered VERB conj → sacred
# Hindu PROPN compound → temples
# temples NOUN dobj → revered
# of ADP prep → temples
# Badrinath PROPN pobj → of
# , PUNCT punct → Badrinath
# Kedarnath PROPN conj → Badrinath
# , PUNCT punct → Kedarnath
# Gangotri PROPN conj → Kedarnath
# and CCONJ cc → Gangotri
# Yamunotri PROPN conj → Gangotri
# are AUX auxpass → nestled
# nestled VERB ROOT → nestled
# in ADP prep → nestled
# the DET det → mountains
# mighty ADJ amod → mountains
# mountains NOUN pobj → in
# . PUNCT punct → nestled
#
# SENTENCE: It’s truly God’s Land (Dev Bhoomi).
# It PRON nsubj → ’s
# ’s VERB ROOT → ’s
# truly ADV advmod → ’s
# God PROPN poss → Land
# ’s PART case → God
# Land PROPN attr → ’s
# ( PUNCT punct → Land
# Dev PROPN compound → Bhoomi
# Bhoomi PROPN appos → Land
# ) PUNCT punct → Land
# . PUNCT punct → ’s
#
# SENTENCE: Dehradun is the Capital of Uttarakhand.
# Dehradun PROPN nsubj → is
# is AUX ROOT → is
# the DET det → Capital
# Capital PROPN attr → is
# of ADP prep → Capital
# Uttarakhand PROPN pobj → of
# . PUNCT punct → is
#
# SENTENCE: It is one of the most beautiful resort in the submountain tracts of India, known for its scenic surroundings.
# It PRON nsubj → is
# is AUX ROOT → is
# one NUM attr → is
# of ADP prep → one
# the DET det → resort
# most ADV advmod → beautiful
# beautiful ADJ amod → resort
# resort NOUN pobj → of
# in ADP prep → resort
# the DET det → tracts
# submountain NOUN compound → tracts
# tracts NOUN pobj → in
# of ADP prep → tracts
# India PROPN pobj → of
# , PUNCT punct → resort
# known VERB acl → resort
# for ADP prep → known
# its PRON poss → surroundings
# scenic ADJ amod → surroundings
# surroundings NOUN pobj → for
# . PUNCT punct → is
#
# SENTENCE: The town lies in the Dun Valley, on the watershed of the Ganga and Yamuna rivers.
# The DET det → town
# town NOUN nsubj → lies
# lies VERB ROOT → lies
# in ADP prep → lies
# the DET det → Valley
# Dun PROPN compound → Valley
# Valley PROPN pobj → in
# , PUNCT punct → lies
# on ADP prep → lies
# the DET det → watershed
# watershed NOUN pobj → on
# of ADP prep → watershed
# the DET det → rivers
# Ganga PROPN nmod → rivers
# and CCONJ cc → Ganga
# Yamuna PROPN conj → Ganga
# rivers NOUN pobj → of
# . PUNCT punct → lies
#
# SENTENCE: It is blessed with a rare bio-diversity, inter-alia, 175 rare species of aromatic & medicinal plants are found in the State.
# It PRON nsubjpass → blessed
# is AUX auxpass → blessed
# blessed VERB ROOT → blessed
# with ADP prep → blessed
# a DET det → bio
# rare ADJ amod → bio
# bio NOUN pobj → with
# - NOUN pobj → with
# diversity NOUN pobj → with
# , PUNCT punct → diversity
# inter ADJ appos → diversity
# - ADJ conj → diversity
# alia ADJ conj → diversity
# , PUNCT punct → diversity
# 175 NUM nummod → species
# rare ADJ amod → species
# species NOUN nsubjpass → found
# of ADP prep → species
# aromatic PROPN amod → plants
# & CCONJ cc → aromatic
# medicinal ADJ conj → aromatic
# plants NOUN pobj → of
# are AUX auxpass → found
# found VERB conj → blessed
# in ADP prep → found
# the DET det → State
# State PROPN pobj → in
# . PUNCT punct → found
#
# SENTENCE: It has almost all major climatic zones, making it amenable to a variety of commercial opportunities in horticulture, floriculture and agriculture.
# It PRON nsubj → has
# has VERB ROOT → has
# almost ADV advmod → all
# all PRON nummod → zones
# major ADJ amod → zones
# climatic ADJ amod → zones
# zones NOUN dobj → has
# , PUNCT punct → has
# making VERB advcl → has
# it PRON nsubj → amenable
# amenable ADJ ccomp → making
# to ADP prep → amenable
# a DET det → variety
# variety NOUN pobj → to
# of ADP prep → variety
# commercial ADJ amod → opportunities
# opportunities NOUN pobj → of
# in ADP prep → opportunities
# horticulture NOUN pobj → in
# , PUNCT punct → horticulture
# floriculture NOUN conj → horticulture
# and CCONJ cc → floriculture
# agriculture NOUN conj → floriculture
# . PUNCT punct → has
#
# SENTENCE: It has a vast tourism potential in adventure, leisure, and eco-tourism.
# It PRON nsubj → has
# has VERB ROOT → has
# a DET det → potential
# vast ADJ amod → potential
# tourism NOUN compound → potential
# potential NOUN dobj → has
# in ADP prep → potential
# adventure NOUN pobj → in
# , PUNCT punct → adventure
# leisure NOUN conj → adventure
# , PUNCT punct → leisure
# and CCONJ cc → leisure
# eco PROPN compound → tourism
# - PUNCT punct → tourism
# tourism NOUN conj → leisure
# . PUNCT punct → has
#
# SENTENCE: The State is rich in mineral deposits like limestone, marble, rock phosphate, dolomite, magnesite, copper, gypsum, etc.
# The DET det → State
# State PROPN nsubj → is
# is AUX ROOT → is
# rich ADJ acomp → is
# in ADP prep → rich
# mineral NOUN compound → deposits
# deposits NOUN pobj → in
# like ADP prep → deposits
# limestone NOUN pobj → like
# , PUNCT punct → limestone
# marble NOUN conj → limestone
# , PUNCT punct → marble
# rock NOUN compound → phosphate
# phosphate NOUN conj → marble
# , PUNCT punct → phosphate
# dolomite NOUN conj → phosphate
# , PUNCT punct → dolomite
# magnesite PROPN conj → dolomite
# , PUNCT punct → magnesite
# copper NOUN conj → magnesite
# , PUNCT punct → copper
# gypsum NOUN conj → copper
# , PUNCT punct → gypsum
# etc X conj → gypsum
# . PUNCT punct → is
#
# SENTENCE: The number of small scale industries is 25,294 providing employment to 63,599 persons.
# The DET det → number
# number NOUN nsubj → is
# of ADP prep → number
# small ADJ amod → scale
# scale NOUN compound → industries
# industries NOUN pobj → of
# is AUX aux → providing
# 25,294 NUM dep → providing
# providing VERB ROOT → providing
# employment NOUN dobj → providing
# to ADP prep → providing
# 63,599 NUM nummod → persons
# persons NOUN pobj → to
# . PUNCT punct → providing
#
# SENTENCE: As many as 1802 heavy and medium industries with an investment of Rs 20,000 crore employ 5 lakh persons.
# As ADV advmod → 1802
# many ADJ amod → 1802
# as ADP quantmod → 1802
# 1802 NUM nummod → industries
# heavy ADJ amod → industries
# and CCONJ cc → heavy
# medium ADJ conj → heavy
# industries NOUN nsubj → employ
# with ADP prep → industries
# an DET det → investment
# investment NOUN pobj → with
# of ADP prep → investment
# Rs NOUN nmod → crore
# 20,000 NUM nummod → crore
# crore NOUN pobj → of
# employ VERB ROOT → employ
# 5 NUM nummod → persons
# lakh NOUN compound → persons
# persons NOUN dobj → employ
# . PUNCT punct → employ
#
# SENTENCE: Most of the industries are forest-based.
# Most ADJ nsubj → are
# of ADP prep → Most
# the DET det → industries
# industries NOUN pobj → of
# are AUX ROOT → are
# forest NOUN npadvmod → based
# - PUNCT punct → based
# based VERB acomp → are
# . PUNCT punct → are
#
# SENTENCE: There is a total of 54,047 handicraft units in the state.
# There PRON expl → is
# is VERB ROOT → is
# a DET det → total
# total NOUN attr → is
# of ADP prep → total
# 54,047 NUM nummod → units
# handicraft NOUN compound → units
# units NOUN pobj → of
# in ADP prep → total
# the DET det → state
# state NOUN pobj → in
# . PUNCT punct → is
#
# SENTENCE: With levels of literacy higher than the national average, the State has abundant availability of quality human resources.
# With ADP prep → has
# levels NOUN pobj → With
# of ADP prep → levels
# literacy NOUN pobj → of
# higher ADJ amod → literacy
# than ADP prep → higher
# the DET det → average
# national ADJ amod → average
# average NOUN pobj → than
# , PUNCT punct → has
# the DET det → State
# State PROPN nsubj → has
# has VERB ROOT → has
# abundant ADJ amod → availability
# availability NOUN dobj → has
# of ADP prep → availability
# quality NOUN amod → resources
# human ADJ amod → resources
# resources NOUN pobj → of
# . PUNCT punct → has
#
# SENTENCE: Within a short span of its existence, Uttarakhand has emerged as a significant destination for investments in manufacturing industry, tourism and infrastructure.
# Within ADP prep → emerged
# a DET det → span
# short ADJ amod → span
# span NOUN pobj → Within
# of ADP prep → span
# its PRON poss → existence
# existence NOUN pobj → of
# , PUNCT punct → emerged
# Uttarakhand PROPN nsubj → emerged
# has AUX aux → emerged
# emerged VERB ROOT → emerged
# as ADP prep → emerged
# a DET det → destination
# significant ADJ amod → destination
# destination NOUN pobj → as
# for ADP prep → destination
# investments NOUN pobj → for
# in ADP prep → investments
# manufacturing NOUN compound → industry
# industry NOUN pobj → in
# , PUNCT punct → industry
# tourism NOUN conj → industry
# and CCONJ cc → tourism
# infrastructure NOUN conj → tourism
# . PUNCT punct → emerged
#
# SENTENCE: Emphasis is on stimulating all three sectors of its economy (agriculture, industry and services), to their fullest potential in tandem with the geographic profile of the state.
# Emphasis NOUN nsubj → is
# is AUX ROOT → is
# on ADP prep → is
# stimulating VERB pcomp → on
# all DET det → sectors
# three NUM nummod → sectors
# sectors NOUN dobj → stimulating
# of ADP prep → sectors
# its PRON poss → economy
# economy NOUN pobj → of
# ( PUNCT punct → economy
# agriculture NOUN appos → economy
# , PUNCT punct → agriculture
# industry NOUN conj → agriculture
# and CCONJ cc → industry
# services NOUN conj → industry
# ) PUNCT punct → stimulating
# , PUNCT punct → is
# to ADP prep → is
# their PRON poss → potential
# fullest ADJ amod → potential
# potential NOUN pobj → to
# in ADP prep → potential
# tandem NOUN pobj → in
# with ADP prep → potential
# the DET det → profile
# geographic ADJ amod → profile
# profile NOUN pobj → with
# of ADP prep → profile
# the DET det → state
# state NOUN pobj → of
# . PUNCT punct → is
#
# SENTENCE: The Government of Uttarakhand has undertaken several policy measures and incentives in order to encourage inflow of investment into the various sectors of its economy.
# The DET det → Government
# Government PROPN nsubj → undertaken
# of ADP prep → Government
# Uttarakhand PROPN pobj → of
# has AUX aux → undertaken
# undertaken VERB ROOT → undertaken
# several ADJ amod → measures
# policy NOUN compound → measures
# measures NOUN dobj → undertaken
# and CCONJ cc → measures
# incentives NOUN conj → measures
# in ADP prep → undertaken
# order NOUN pobj → in
# to PART aux → encourage
# encourage VERB acl → order
# inflow NOUN dobj → encourage
# of ADP prep → inflow
# investment NOUN pobj → of
# into ADP prep → encourage
# the DET det → sectors
# various ADJ amod → sectors
# sectors NOUN pobj → into
# of ADP prep → sectors
# its PRON poss → economy
# economy NOUN pobj → of
# . PUNCT punct → undertaken
#
# SENTENCE: [Type text] Page 1 1.
# [ X nmod → text
# Type NOUN compound → text
# text NOUN ROOT → text
# ] PUNCT punct → text
# Page NOUN appos → text
# 1 NUM nummod → Page
# 1 NUM nummod → Page
# . PUNCT punct → text
#
# SENTENCE: Weather of State: The climatic conditions experienced in Uttarakhand vary from hot and moist subtropical in the southern part to cold alpine in the upper reaches of the Himalayan mountain in the northern parts.
# Weather PROPN nsubj → vary
# of ADP prep → Weather
# State PROPN pobj → of
# : PUNCT punct → Weather
# The DET det → conditions
# climatic ADJ amod → conditions
# conditions NOUN nsubj → vary
# experienced VERB acl → conditions
# in ADP prep → experienced
# Uttarakhand PROPN pobj → in
# vary VERB ROOT → vary
# from ADP prep → vary
# hot ADJ amod → subtropical
# and CCONJ cc → hot
# moist ADJ conj → hot
# subtropical ADJ pobj → from
# in ADP prep → vary
# the DET det → part
# southern ADJ amod → part
# part NOUN pobj → in
# to ADP prep → vary
# cold ADJ amod → alpine
# alpine NOUN pobj → to
# in ADP prep → alpine
# the DET det → reaches
# upper ADJ amod → reaches
# reaches NOUN pobj → in
# of ADP prep → reaches
# the DET det → mountain
# Himalayan ADJ amod → mountain
# mountain NOUN pobj → of
# in ADP prep → reaches
# the DET det → parts
# northern ADJ amod → parts
# parts NOUN pobj → in
# . PUNCT punct → vary
#
# SENTENCE: Warm and cool temperate climate persists over the areas between southern and northern parts of the state.
# Warm ADJ amod → climate
# and CCONJ cc → Warm
# cool ADJ conj → Warm
# temperate NOUN compound → climate
# climate NOUN nsubj → persists
# persists VERB ROOT → persists
# over ADP prep → persists
# the DET det → areas
# areas NOUN pobj → over
# between ADP prep → areas
# southern ADJ amod → parts
# and CCONJ cc → southern
# northern ADJ conj → southern
# parts NOUN pobj → between
# of ADP prep → parts
# the DET det → state
# state NOUN pobj → of
# . PUNCT punct → persists
#
# SENTENCE: The climate at particular place in the state is influenced by (a) Altitude/ elevation (b) Latitude or location (c) Slope and topography.
# The DET det → climate
# climate NOUN nsubjpass → influenced
# at ADP prep → climate
# particular ADJ amod → place
# place NOUN pobj → at
# in ADP prep → place
# the DET det → state
# state NOUN pobj → in
# is AUX auxpass → influenced
# influenced VERB ROOT → influenced
# by ADP agent → influenced
# ( PUNCT punct → Latitude
# a X nmod → Latitude
# ) PUNCT punct → elevation
# Altitude/ PROPN compound → elevation
# elevation NOUN nmod → Latitude
# ( PUNCT punct → b
# b NOUN appos → elevation
# ) PUNCT punct → b
# Latitude NOUN pobj → by
# or CCONJ cc → Latitude
# location NOUN conj → Latitude
# ( PUNCT punct → c
# c NOUN appos → location
# ) PUNCT punct → c
# Slope NOUN conj → Latitude
# and CCONJ cc → Slope
# topography NOUN conj → Slope
# . PUNCT punct → influenced
#
# SENTENCE: The climate of Uttarakhand is sharply demarcated in case of two distinct divisions the predominant hilly terrain and the smaller plain region.
# The DET det → climate
# climate NOUN nsubjpass → demarcated
# of ADP prep → climate
# Uttarakhand PROPN pobj → of
# is AUX auxpass → demarcated
# sharply ADV advmod → demarcated
# demarcated VERB ROOT → demarcated
# in ADP prep → demarcated
# case NOUN pobj → in
# of ADP prep → case
# two NUM nummod → divisions
# distinct ADJ amod → divisions
# divisions NOUN pobj → of
# the DET det → terrain
# predominant ADJ amod → terrain
# hilly ADJ amod → terrain
# terrain NOUN dobj → demarcated
# and CCONJ cc → terrain
# the DET det → region
# smaller ADJ amod → region
# plain ADJ amod → region
# region NOUN conj → terrain
# . PUNCT punct → demarcated
#
# SENTENCE: The areas of high hills even become inaccessible in winter due to extreme cold of climate causing prolonged snowfall.
# The DET det → areas
# areas NOUN nsubj → become
# of ADP prep → areas
# high ADJ amod → hills
# hills NOUN pobj → of
# even ADV advmod → become
# become VERB ROOT → become
# inaccessible ADJ acomp → become
# in ADP prep → become
# winter NOUN pobj → in
# due ADP prep → become
# to ADP pcomp → due
# extreme ADJ amod → cold
# cold NOUN pobj → due
# of ADP prep → cold
# climate NOUN pobj → of
# causing VERB advcl → become
# prolonged ADJ amod → snowfall
# snowfall NOUN dobj → causing
# . PUNCT punct → become
#
# SENTENCE: The mountain range itself exerts an appreciable extent of influence on monsoon and rainfall patterns.
# The DET det → range
# mountain NOUN compound → range
# range NOUN nsubj → exerts
# itself PRON appos → range
# exerts VERB ROOT → exerts
# an DET det → extent
# appreciable ADJ amod → extent
# extent NOUN dobj → exerts
# of ADP prep → extent
# influence NOUN pobj → of
# on ADP prep → influence
# monsoon NOUN nmod → patterns
# and CCONJ cc → monsoon
# rainfall NOUN conj → monsoon
# patterns NOUN pobj → on
# . PUNCT punct → exerts
#
# SENTENCE: Cold alpine climate is experienced at higher reaches where summers are cool and winters are harsh.
# Cold ADJ amod → climate
# alpine NOUN compound → climate
# climate NOUN nsubjpass → experienced
# is AUX auxpass → experienced
# experienced VERB ROOT → experienced
# at ADP prep → experienced
# higher ADJ amod → reaches
# reaches NOUN pobj → at
# where SCONJ advmod → are
# summers NOUN nsubj → are
# are AUX relcl → reaches
# cool ADJ acomp → are
# and CCONJ cc → are
# winters NOUN nsubj → are
# are AUX conj → are
# harsh ADJ acomp → are
# . PUNCT punct → are
#
# SENTENCE: At altitudes over 4800 m, the climate is bitterly cold with temperatures consistently below the freezing point of water and the area is perennially shrouded in snow and ice.
# At ADP prep → is
# altitudes NOUN pobj → At
# over ADP prep → altitudes
# 4800 NUM nummod → m
# m NOUN pobj → over
# , PUNCT punct → is
# the DET det → climate
# climate NOUN nsubj → is
# is AUX ROOT → is
# bitterly ADV advmod → cold
# cold ADJ acomp → is
# with ADP prep → cold
# temperatures NOUN pobj → with
# consistently ADV advmod → below
# below ADP prep → temperatures
# the DET det → point
# freezing ADJ amod → point
# point NOUN pobj → below
# of ADP prep → point
# water NOUN pobj → of
# and CCONJ cc → is
# the DET det → area
# area NOUN nsubjpass → shrouded
# is AUX auxpass → shrouded
# perennially ADV advmod → shrouded
# shrouded VERB conj → is
# in ADP prep → shrouded
# snow NOUN pobj → in
# and CCONJ cc → snow
# ice NOUN conj → snow
# . PUNCT punct → shrouded
#
# SENTENCE: In general the year may be divided into four seasons.
# In ADP prep → divided
# general ADJ amod → In
# the DET det → year
# year NOUN nsubjpass → divided
# may AUX aux → divided
# be AUX auxpass → divided
# divided VERB ROOT → divided
# into ADP prep → divided
# four NUM nummod → seasons
# seasons NOUN pobj → into
# . PUNCT punct → divided
#
# SENTENCE: The winter season from December to February is followed by pre-monsoon or hot weather season from March to May.
# The DET det → season
# winter NOUN compound → season
# season NOUN nsubjpass → followed
# from ADP prep → season
# December PROPN pobj → from
# to ADP prep → from
# February PROPN pobj → to
# is AUX auxpass → followed
# followed VERB ROOT → followed
# by ADP agent → followed
# pre ADJ amod → season
# - ADJ amod → season
# monsoon ADJ amod → season
# or CCONJ cc → monsoon
# hot ADJ conj → monsoon
# weather NOUN compound → season
# season NOUN pobj → by
# from ADP prep → followed
# March PROPN pobj → from
# to ADP prep → from
# May PROPN pobj → to
# . PUNCT punct → followed
#
# SENTENCE: June to September constitutes the southwest monsoon season and the period of October and November is of post monsoon season.
# June PROPN npadvmod → constitutes
# to ADP prep → constitutes
# September PROPN pobj → to
# constitutes VERB ROOT → constitutes
# the DET det → season
# southwest ADJ amod → season
# monsoon NOUN compound → season
# season NOUN dobj → constitutes
# and CCONJ cc → season
# the DET det → period
# period NOUN conj → season
# of ADP prep → period
# October PROPN pobj → of
# and CCONJ cc → October
# November PROPN conj → October
# is AUX conj → constitutes
# of ADP prep → is
# post NOUN compound → season
# monsoon NOUN compound → season
# season NOUN pobj → of
# . PUNCT punct → constitutes
#
# SENTENCE: The state is divided in to two regions viz.
# The DET det → state
# state NOUN nsubjpass → divided
# is AUX auxpass → divided
# divided VERB ROOT → divided
# in ADP prep → divided
# to ADP prep → divided
# two NUM nummod → regions
# regions NOUN pobj → to
# viz VERB advcl → divided
# . PUNCT punct → divided
#
# SENTENCE: western part is known as Garhwal region and eastern part is Kumaun region.
# western ADJ amod → part
# part NOUN nsubjpass → known
# is AUX auxpass → known
# known VERB ROOT → known
# as ADP prep → known
# Garhwal PROPN compound → region
# region NOUN pobj → as
# and CCONJ cc → region
# eastern ADJ amod → part
# part NOUN conj → region
# is AUX advcl → known
# Kumaun ADJ amod → region
# region NOUN attr → is
# . PUNCT punct → known
#
# SENTENCE: Garhwal region consists of Chamoli, Dehradun, Hardwar, Pauri Garhwal , Rudraprayag, Tehri Garhwal and Uttarkashi districts.
# Garhwal PROPN compound → region
# region NOUN nsubj → consists
# consists VERB ROOT → consists
# of ADP prep → consists
# Chamoli PROPN nmod → districts
# , PUNCT punct → Chamoli
# Dehradun PROPN conj → Chamoli
# , PUNCT punct → Dehradun
# Hardwar PROPN conj → Dehradun
# , PUNCT punct → Hardwar
# Pauri PROPN compound → Garhwal
# Garhwal PROPN conj → Hardwar
# , PUNCT punct → Garhwal
# Rudraprayag PROPN conj → Garhwal
# , PUNCT punct → Rudraprayag
# Tehri PROPN compound → Garhwal
# Garhwal PROPN conj → Rudraprayag
# and CCONJ cc → Garhwal
# Uttarkashi PROPN conj → Garhwal
# districts NOUN pobj → of
# . PUNCT punct → consists
#
# SENTENCE: Kumaun region consists of Almora, Bageshwar, Champawat, Nainital , Pithoragarh and U S Nagar.
# Kumaun ADJ amod → region
# region NOUN nsubj → consists
# consists VERB ROOT → consists
# of ADP prep → consists
# Almora PROPN pobj → of
# , PUNCT punct → Almora
# Bageshwar PROPN conj → Almora
# , PUNCT punct → Bageshwar
# Champawat PROPN conj → Bageshwar
# , PUNCT punct → Champawat
# Nainital PROPN conj → Champawat
# , PUNCT punct → Nainital
# Pithoragarh PROPN conj → Nainital
# and CCONJ cc → Pithoragarh
# U PROPN compound → Nagar
# S PROPN compound → Nagar
# Nagar PROPN conj → Pithoragarh
# . PUNCT punct → consists
#
# SENTENCE: [Type text] Page 2 2.
# [ X nmod → text
# Type NOUN compound → text
# text NOUN ROOT → text
# ] PUNCT punct → text
# Page NOUN appos → text
# 2 NUM nummod → Page
# 2 NUM nummod → Page
# . PUNCT punct → text
#
# SENTENCE: Agro Climatic / Ecological Zones: Climatically the State is situated in the Temperate Zone.
# Agro PROPN compound → Zones
# Climatic PROPN nmod → Ecological
# / SYM punct → Ecological
# Ecological PROPN compound → Zones
# Zones NOUN nsubjpass → situated
# : PUNCT punct → Zones
# Climatically ADV advmod → situated
# the DET det → State
# State PROPN nsubjpass → situated
# is AUX auxpass → situated
# situated VERB ROOT → situated
# in ADP prep → situated
# the DET det → Zone
# Temperate PROPN compound → Zone
# Zone PROPN pobj → in
# . PUNCT punct → situated
#
# SENTENCE: However, the climate varies from sultry hot in the foot hills to arctic cold in snow capped peaks with subtropical climates in the river valleys.
# However ADV advmod → varies
# , PUNCT punct → varies
# the DET det → climate
# climate NOUN nsubj → varies
# varies VERB ROOT → varies
# from ADP prep → varies
# sultry NOUN pobj → from
# hot ADJ amod → sultry
# in ADP prep → varies
# the DET det → hills
# foot NOUN compound → hills
# hills NOUN pobj → in
# to ADP prep → varies
# arctic ADJ amod → cold
# cold PROPN pobj → to
# in ADP prep → varies
# snow NOUN npadvmod → capped
# capped VERB amod → peaks
# peaks NOUN pobj → in
# with ADP prep → varies
# subtropical ADJ amod → climates
# climates NOUN pobj → with
# in ADP prep → climates
# the DET det → valleys
# river NOUN compound → valleys
# valleys NOUN pobj → in
# . PUNCT punct → varies
#
# SENTENCE: Physiographically, the region is divided into following 4 sub agro-climatic zones.
# Physiographically ADV advmod → divided
# , PUNCT punct → divided
# the DET det → region
# region NOUN nsubjpass → divided
# is AUX auxpass → divided
# divided VERB ROOT → divided
# into ADP prep → divided
# following VERB pcomp → into
# 4 NUM nummod → zones
# sub NOUN nmod → zones
# agro ADJ amod → climatic
# - PUNCT punct → climatic
# climatic ADJ amod → zones
# zones NOUN dobj → following
# . PUNCT punct → divided
#
# SENTENCE: i.e. (i)
# i.e. X advmod → i
# ( PUNCT punct → i
# i NOUN ROOT → i
# ) PUNCT punct → i
#
# SENTENCE: The outer Himalayas Zone or Shivalik hills which is located at 500 to 1250 m above mean sea level (ii)The lesser Himalayas Zone located at 1250 to 2750 m above mean sea level (iii)
# The DET det → Zone
# outer ADJ amod → Zone
# Himalayas PROPN compound → Zone
# Zone PROPN ROOT → Zone
# or CCONJ cc → Zone
# Shivalik PROPN compound → hills
# hills NOUN conj → Zone
# which PRON nsubjpass → located
# is AUX auxpass → located
# located VERB relcl → hills
# at ADP prep → located
# 500 NUM quantmod → 1250
# to PART quantmod → 1250
# 1250 NUM nummod → m
# m NOUN pobj → at
# above ADP prep → m
# mean ADJ amod → level
# sea NOUN compound → level
# level NOUN pobj → above
# ( PUNCT punct → level
# ii)The NOUN nmod → Zone
# lesser ADJ amod → Zone
# Himalayas PROPN compound → Zone
# Zone PROPN appos → level
# located VERB acl → Zone
# at ADP prep → located
# 1250 NUM pobj → at
# to ADP prep → located
# 2750 NUM pobj → to
# m NOUN appos → Zone
# above ADP prep → Zone
# mean VERB amod → level
# sea NOUN compound → level
# level NOUN pobj → above
# ( PUNCT punct → level
# iii PROPN appos → level
# ) PUNCT punct → level
#
# SENTENCE: The Great Himalayas Zone located at 2750 to 4500 m above mean sea level and (iv) The Trans Himalayas Zone located at 4500 m above mean sea level [Type text] Page 3 3.
# The DET det → Zone
# Great PROPN compound → Zone
# Himalayas PROPN compound → Zone
# Zone PROPN nsubj → level
# located VERB acl → Zone
# at ADP prep → located
# 2750 NUM pobj → at
# to ADP prep → located
# 4500 NUM nummod → m
# m NOUN pobj → to
# above ADP prep → m
# mean ADJ amod → level
# sea NOUN compound → level
# level NOUN pobj → above
# and CCONJ cc → Zone
# ( PUNCT punct → iv
# iv X conj → Zone
# ) PUNCT punct → iv
# The DET det → Zone
# Trans PROPN compound → Zone
# Himalayas PROPN compound → Zone
# Zone PROPN appos → Zone
# located VERB acl → Zone
# at ADP prep → located
# 4500 NUM nummod → m
# m NOUN pobj → at
# above ADP prep → m
# mean ADJ amod → level
# sea NOUN compound → level
# level NOUN ROOT → level
# [ X nmod → text
# Type NOUN compound → text
# text NOUN appos → level
# ] PUNCT punct → text
# Page NOUN appos → level
# 3 NUM nummod → Page
# 3 NUM nummod → Page
# . PUNCT punct → level
#
# SENTENCE: Soil Type: S.No.
# Soil PROPN compound → Type
# Type PROPN ROOT → Type
# : PUNCT punct → Type
# S.No PROPN appos → Type
# . PUNCT punct → Type
#
# SENTENCE: Type of Soils No. of Districts Name of Districts 1.
# Type NOUN ROOT → Type
# of ADP prep → Type
# Soils PROPN compound → No
# No PROPN pobj → of
# . NOUN pobj → of
# of ADP prep → .
# Districts PROPN compound → Name
# Name NOUN pobj → of
# of ADP prep → Name
# Districts NOUN pobj → of
# 1 NUM nummod → Districts
# . PUNCT punct → Type
#
# SENTENCE: Alluvial 2 Udham Singh Nagar & Haridwar 2.
# Alluvial ADJ amod → 2
# 2 NUM nummod → Nagar
# Udham PROPN compound → Nagar
# Singh PROPN compound → Nagar
# Nagar PROPN ROOT → Nagar
# & CCONJ cc → Nagar
# Haridwar PROPN conj → Nagar
# 2 NUM nummod → Nagar
# . PUNCT punct → Nagar
#
# SENTENCE: Alluvial mixed with 3 Nainital, Dehradun & Pauri Garhwal boulders and shingles 3.
# Alluvial PROPN nsubj → mixed
# mixed VERB ROOT → mixed
# with ADP prep → mixed
# 3 NUM nummod → Nainital
# Nainital PROPN pobj → with
# , PUNCT punct → Nainital
# Dehradun PROPN conj → Nainital
# & CCONJ cc → Dehradun
# Pauri PROPN compound → Garhwal
# Garhwal PROPN conj → Dehradun
# boulders NOUN appos → Nainital
# and CCONJ cc → boulders
# shingles NOUN conj → boulders
# 3 NUM dobj → shingles
# . PUNCT punct → mixed
#
# SENTENCE: Alluvial Sandy Soil 5 Champawat, Pauri Garhwal, Dehradun, Nainital & Terhi Garhwal 4.
# Alluvial PROPN compound → Champawat
# Sandy PROPN compound → Soil
# Soil PROPN nmod → Champawat
# 5 NUM nummod → Soil
# Champawat PROPN ROOT → Champawat
# , PUNCT punct → Champawat
# Pauri PROPN compound → Garhwal
# Garhwal PROPN conj → Champawat
# , PUNCT punct → Garhwal
# Dehradun PROPN conj → Garhwal
# , PUNCT punct → Dehradun
# Nainital PROPN conj → Dehradun
# & CCONJ cc → Nainital
# Terhi PROPN conj → Nainital
# Garhwal PROPN appos → Champawat
# 4 NUM nummod → Garhwal
# . PUNCT punct → Champawat
#
# SENTENCE: Residual Sandy Soil 6 Champawat, Pauri Garhwal, Dehradun, Nainital, Terhi Garhwal & Bageshwar 5.
# Residual ADJ amod → Soil
# Sandy PROPN compound → Soil
# Soil PROPN nmod → Champawat
# 6 NUM nummod → Soil
# Champawat PROPN ROOT → Champawat
# , PUNCT punct → Champawat
# Pauri PROPN compound → Garhwal
# Garhwal PROPN conj → Champawat
# , PUNCT punct → Garhwal
# Dehradun PROPN conj → Garhwal
# , PUNCT punct → Dehradun
# Nainital PROPN conj → Dehradun
# , PUNCT punct → Nainital
# Terhi PROPN compound → Garhwal
# Garhwal PROPN conj → Nainital
# & CCONJ cc → Garhwal
# Bageshwar PROPN conj → Garhwal
# 5 NUM nummod → Bageshwar
# . PUNCT punct → Champawat
#
# SENTENCE: Sandy Loam 6 Champawat, Nainital, Almora, Dehradun, Terhi Garhwal & Bageshwar 6.
# Sandy PROPN nmod → Champawat
# Loam PROPN nmod → Champawat
# 6 NUM nummod → Loam
# Champawat PROPN ROOT → Champawat
# , PUNCT punct → Champawat
# Nainital PROPN conj → Champawat
# , PUNCT punct → Nainital
# Almora PROPN conj → Nainital
# , PUNCT punct → Almora
# Dehradun PROPN conj → Almora
# , PUNCT punct → Dehradun
# Terhi PROPN compound → Garhwal
# Garhwal PROPN conj → Dehradun
# & CCONJ cc → Garhwal
# Bageshwar PROPN conj → Garhwal
# 6 NUM nummod → Bageshwar
# . PUNCT punct → Champawat
#
# SENTENCE: Red to Dark 4 Pithoragarh, Almora, Chamoli & Bageshwar 7.
# Red ADJ ROOT → Red
# to ADP prep → Red
# Dark PROPN nmod → Pithoragarh
# 4 NUM nummod → Pithoragarh
# Pithoragarh PROPN pobj → to
# , PUNCT punct → Pithoragarh
# Almora PROPN conj → Pithoragarh
# , PUNCT punct → Almora
# Chamoli PROPN conj → Almora
# & CCONJ cc → Chamoli
# Bageshwar PROPN conj → Chamoli
# 7 NUM nummod → Bageshwar
# . PUNCT punct → Red
#
# SENTENCE: Red to dark 3 Pithoragarh, Chamoli & Uttarkashi Black clay
# Red ADJ amod → Pithoragarh
# to ADP prep → Red
# dark ADJ pobj → to
# 3 NUM nummod → Pithoragarh
# Pithoragarh PROPN ROOT → Pithoragarh
# , PUNCT punct → Pithoragarh
# Chamoli PROPN conj → Pithoragarh
# & CCONJ cc → Chamoli
# Uttarkashi PROPN compound → Black
# Black PROPN compound → clay
# clay NOUN conj → Chamoli
#
# SENTENCE: [Type text] Page 4 4.
# [ X nmod → text
# Type NOUN compound → text
# text NOUN ROOT → text
# ] PUNCT punct → text
# Page NOUN appos → text
# 4 NUM nummod → Page
# 4 NUM nummod → Page
# . PUNCT punct → text
#
# SENTENCE: Major Crops: S. No. Commodity Major Crops Kharif Rabi 1.
# Major ADJ amod → Crops
# Crops PROPN ROOT → Crops
# : PUNCT punct → Crops
# S. PROPN compound → No
# No NOUN nmod → Rabi
# . PUNCT punct → No
# Commodity PROPN compound → Major
# Major PROPN compound → Crops
# Crops PROPN compound → Rabi
# Kharif PROPN compound → Rabi
# Rabi PROPN appos → Crops
# 1 NUM nummod → Rabi
# . PUNCT punct → Rabi
#
# SENTENCE: Cereals Paddy & Maize Wheat & Barley 2. Nutri-
# Cereals PROPN compound → Paddy
# Paddy PROPN ROOT → Paddy
# & CCONJ cc → Paddy
# Maize PROPN compound → Wheat
# Wheat PROPN conj → Paddy
# & CCONJ cc → Wheat
# Barley PROPN conj → Wheat
# 2 NUM nummod → Barley
# . PUNCT punct → Paddy
# Nutri- PROPN punct → Paddy
#
# SENTENCE: Cereals Barnyard Millets, Mandua 3.
# Cereals NOUN compound → Millets
# Barnyard PROPN compound → Millets
# Millets PROPN ROOT → Millets
# , PUNCT punct → Millets
# Mandua PROPN appos → Millets
# 3 NUM nummod → Mandua
# . PUNCT punct → Millets
#
# SENTENCE: Pulses Urd, Tur & Mung Gram, Pea & Lentil 4.
# Pulses PROPN compound → Urd
# Urd PROPN ROOT → Urd
# , PUNCT punct → Urd
# Tur PROPN conj → Urd
# & CCONJ cc → Tur
# Mung PROPN compound → Gram
# Gram PROPN conj → Tur
# , PUNCT punct → Gram
# Pea PROPN conj → Gram
# & CCONJ cc → Pea
# Lentil PROPN conj → Pea
# 4 NUM nummod → Lentil
# . PUNCT punct → Urd
#
# SENTENCE: Oilseeds Groundnut, Soybean Mustard & Linseed 5.
# Oilseeds PROPN compound → Groundnut
# Groundnut PROPN ROOT → Groundnut
# , PUNCT punct → Groundnut
# Soybean PROPN compound → Mustard
# Mustard PROPN conj → Groundnut
# & CCONJ cc → Mustard
# Linseed PROPN conj → Mustard
# 5 NUM nummod → Linseed
# . PUNCT punct → Groundnut
#
# SENTENCE: Commercial Crops Sugarcane 5.
# Commercial PROPN compound → Crops
# Crops PROPN compound → Sugarcane
# Sugarcane PROPN ROOT → Sugarcane
# 5 NUM nummod → Sugarcane
# . PUNCT punct → Sugarcane
#
# SENTENCE: Major Varieties Crop-wise (Less than 10 Year): Crops Release/Notifi Varieties ed Year Cereals 2014 VL 68, CR Dhan 303 (IET 21589) 2015 Pusa Basmati 1609 (IET 22778)
# Major PROPN amod → Varieties
# Varieties PROPN compound → Crop
# Crop PROPN npadvmod → wise
# - PUNCT punct → wise
# wise ADJ ROOT → wise
# ( PUNCT punct → Year
# Less ADJ amod → 10
# than ADP quantmod → 10
# 10 NUM nummod → Year
# Year PROPN appos → wise
# ): PUNCT punct → wise
# Crops PROPN compound → Varieties
# Release PROPN nmod → Notifi
# / SYM punct → Notifi
# Notifi PROPN compound → Varieties
# Varieties PROPN compound → ed
# ed PROPN compound → Year
# Year PROPN compound → Cereals
# Cereals NOUN appos → wise
# 2014 NUM nummod → VL
# VL PROPN appos → Cereals
# 68 NUM nummod → VL
# , PUNCT punct → Cereals
# CR PROPN compound → Dhan
# Dhan PROPN appos → Cereals
# 303 NUM nummod → Dhan
# ( PUNCT punct → Dhan
# IET PROPN appos → Dhan
# 21589 NUM nummod → IET
# ) PUNCT punct → IET
# 2015 NUM punct → wise
# Pusa PROPN compound → Basmati
# Basmati PROPN appos → wise
# 1609 NUM nummod → Basmati
# ( PUNCT punct → IET
# IET PROPN appos → Basmati
# 22778 NUM nummod → IET
# ) PUNCT punct → Basmati
#
# SENTENCE: Paddy HRI Hybrid 180, Pant Dhan-26 (UPR 3425-14-3-1), 2017 Pantt Dhan 26 2020 Pant Dhan 28 2015 Shalimar Wheat-2 (SKW-355)
# Paddy PROPN compound → HRI
# HRI PROPN compound → Hybrid
# Hybrid PROPN ROOT → Hybrid
# 180 NUM nummod → Hybrid
# , PUNCT punct → Hybrid
# Pant PROPN compound → Dhan-26
# Dhan-26 PROPN appos → Hybrid
# ( PUNCT punct → Dhan-26
# UPR PROPN appos → Dhan-26
# 3425 NUM nummod → UPR
# - PUNCT punct → UPR
# 14 NUM nummod → UPR
# - PUNCT punct → UPR
# 3 NUM nummod → UPR
# - SYM punct → 1
# 1 NUM prep → 3
# ) PUNCT punct → Dhan-26
# , PUNCT punct → Dhan-26
# 2017 NUM appos → Dhan-26
# Pantt PROPN compound → Dhan
# Dhan PROPN appos → Dhan-26
# 26 NUM nummod → 2020
# 2020 NUM nummod → Dhan
# Pant PROPN compound → Dhan
# Dhan PROPN appos → Dhan-26
# 28 NUM nummod → Dhan
# 2015 NUM npadvmod → 28
# Shalimar PROPN compound → Wheat-2
# Wheat-2 PROPN appos → Dhan
# ( PUNCT punct → Wheat-2
# SKW-355 PROPN appos → Wheat-2
# ) PUNCT punct → SKW-355
#
# SENTENCE: 2016 VL 953 Wheat 2017 PBW-1Zn 2020 PBW-771, Pusa Wheat-1628 2021 DBW 187 (Karan Vandana), DBW-100 Barley 2016 VLB 94 Maize 2017 VL 55 Pulses Black Gram 2020 Pant Urd-7, Pant Urd-8, Pant Urd-9 Chick Pea 2017 Pant Gram-4 (PG 065), PKC-2(PG-71)
# 2016 NUM nummod → PBW-771
# VL NOUN nmod → PBW-771
# 953 NUM nummod → PBW-771
# Wheat PROPN nmod → PBW-1Zn
# 2017 NUM nummod → Wheat
# PBW-1Zn PROPN nmod → PBW-771
# 2020 NUM nummod → PBW-1Zn
# PBW-771 PROPN nmod → Urd-7
# , PUNCT punct → PBW-771
# Pusa PROPN compound → Wheat-1628
# Wheat-1628 PROPN nmod → DBW
# 2021 NUM nummod → Wheat-1628
# DBW PROPN appos → PBW-771
# 187 NUM nummod → DBW
# ( PUNCT punct → DBW
# Karan PROPN compound → Vandana
# Vandana PROPN appos → DBW
# ) PUNCT punct → DBW
# , PUNCT punct → PBW-771
# DBW-100 PROPN compound → VLB
# Barley PROPN nmod → VLB
# 2016 NUM nummod → Barley
# VLB PROPN appos → PBW-771
# 94 NUM nummod → VLB
# Maize PROPN appos → PBW-771
# 2017 NUM nummod → Maize
# VL PROPN appos → PBW-771
# 55 NUM nummod → Pulses
# Pulses PROPN compound → Gram
# Black PROPN compound → Gram
# Gram PROPN appos → PBW-771
# 2020 NUM nummod → Gram
# Pant PROPN compound → Urd-7
# Urd-7 PROPN ROOT → Urd-7
# , PUNCT punct → Urd-7
# Pant PROPN compound → Urd-8
# Urd-8 PROPN conj → Urd-7
# , PUNCT punct → Urd-8
# Pant PROPN compound → Pea
# Urd-9 PROPN compound → Pea
# Chick PROPN compound → Pea
# Pea PROPN conj → Urd-8
# 2017 NUM cc → Pea
# Pant PROPN compound → Gram-4
# Gram-4 PROPN appos → Urd-7
# ( PUNCT punct → Gram-4
# PG PROPN appos → Gram-4
# 065 NUM nummod → PG
# ) PUNCT punct → Gram-4
# , PUNCT punct → Gram-4
# PKC-2(PG-71 PROPN appos → Gram-4
# ) PUNCT punct → Urd-7
#
# SENTENCE: Green Gram 2020 Pant Moong-8, Pant Moong-9 Lentil 2020 VL-148 Pea 2020 VL Matar 61(VL 61) Pigeon Pea 2020 Pant Arhar 7 Finger Millet 2017 VL 376 [Type text] Page 5 Crops Release/Notifi Varieties ed Year Oilseeds R&M 2020 Pant Girija 2016 VLS-77 Soybean 2019 VLS-89 2020 Uttarakhand Black SoybeanVL Bhat-202
# Green PROPN compound → Gram
# Gram PROPN nmod → Moong-8
# 2020 NUM nummod → Gram
# Pant PROPN compound → Moong-8
# Moong-8 PROPN ROOT → Moong-8
# , PUNCT punct → Moong-8
# Pant PROPN compound → Moong-9
# Moong-9 PROPN appos → Moong-8
# Lentil PROPN prep → Moong-8
# 2020 NUM nummod → Pea
# VL-148 PROPN compound → Pea
# Pea PROPN appos → Lentil
# 2020 NUM nummod → Pea
# VL PROPN compound → Matar
# Matar PROPN nmod → Arhar
# 61(VL NUM nummod → 61
# 61 NUM nummod → Matar
# ) PUNCT punct → Matar
# Pigeon PROPN compound → Pea
# Pea PROPN appos → Matar
# 2020 NUM nummod → Pea
# Pant PROPN compound → Arhar
# Arhar PROPN nmod → Finger
# 7 NUM nummod → Finger
# Finger PROPN nmod → VL
# Millet PROPN nmod → VL
# 2017 NUM nummod → Millet
# VL PROPN punct → Moong-8
# 376 NUM nummod → text
# [ X nmod → text
# Type NOUN compound → text
# text NOUN appos → Moong-8
# ] PUNCT punct → Moong-8
# Page NOUN nmod → Varieties
# 5 NUM nummod → Page
# Crops PROPN compound → Varieties
# Release PROPN nmod → Notifi
# / SYM punct → Notifi
# Notifi PROPN compound → Varieties
# Varieties PROPN compound → ed
# ed PROPN compound → Year
# Year PROPN compound → Oilseeds
# Oilseeds PROPN compound → SoybeanVL
# R&M PROPN nmod → SoybeanVL
# 2020 NUM nummod → R&M
# Pant PROPN compound → Girija
# Girija PROPN nmod → SoybeanVL
# 2016 NUM nummod → Girija
# VLS-77 PROPN nmod → Soybean
# Soybean PROPN nmod → SoybeanVL
# 2019 NUM nummod → Soybean
# VLS-89 PROPN nmod → Uttarakhand
# 2020 NUM nummod → VLS-89
# Uttarakhand PROPN compound → SoybeanVL
# Black PROPN compound → SoybeanVL
# SoybeanVL PROPN appos → Moong-8
# Bhat-202 PUNCT punct → Moong-8
#
# SENTENCE: Commercial Crop 2017 Co 09022 (Karan 12), CoLk 9204 (Ikshu 3), 2018 CoLK 09204 (Ikshu- 3) 2021 Co 15023 (Karan 15) Sugarcane CoLk 15207 (Ikshu-12), CoLk 15201 (Ikshu-11), CoPb 98, 2022 (CoPb CoLK 14204- IKSHU-814185) 6.
# Commercial PROPN compound → Co
# Crop PROPN nmod → Co
# 2017 NUM nummod → Crop
# Co PROPN ROOT → Co
# 09022 NUM nummod → Co
# ( PUNCT punct → Co
# Karan PROPN appos → Co
# 12 NUM nummod → Karan
# ) PUNCT punct → Karan
# , PUNCT punct → Co
# CoLk PROPN npadvmod → Co
# 9204 NUM nummod → CoLk
# ( PUNCT punct → CoLk
# Ikshu PROPN appos → CoLk
# 3 NUM nummod → Ikshu
# ) PUNCT punct → CoLk
# , PUNCT punct → CoLk
# 2018 NUM conj → CoLk
# CoLK PROPN appos → CoLk
# 09204 NUM appos → CoLK
# ( PUNCT punct → CoLk
# Ikshu- PROPN appos → CoLk
# 3 NUM nummod → Ikshu-
# ) PUNCT punct → Ikshu-
# 2021 NUM nummod → Ikshu-
# Co PROPN appos → CoLk
# 15023 NUM nummod → CoLk
# ( PUNCT punct → CoLk
# Karan PROPN appos → CoLk
# 15 NUM nummod → Karan
# ) PUNCT punct → CoLk
# Sugarcane PROPN compound → CoLk
# CoLk PROPN appos → CoLk
# 15207 NUM nummod → CoLk
# ( PUNCT punct → CoLk
# Ikshu-12 PROPN appos → CoLk
# ) PUNCT punct → CoLk
# , PUNCT punct → CoLk
# CoLk PROPN appos → CoLk
# 15201 NUM nummod → CoLk
# ( PUNCT punct → CoLk
# Ikshu-11 PROPN appos → CoLk
# ) PUNCT punct → CoLk
# , PUNCT punct → CoLk
# CoPb PROPN appos → CoLk
# 98 NUM nummod → CoPb
# , PUNCT punct → CoPb
# 2022 NUM appos → CoPb
# ( PUNCT punct → CoLk
# CoPb PROPN compound → IKSHU-814185
# CoLK PROPN compound → IKSHU-814185
# 14204- PROPN compound → IKSHU-814185
# IKSHU-814185 PROPN appos → CoLk
# ) PUNCT punct → Co
# 6 NUM appos → Co
# . PUNCT punct → Co
#
# SENTENCE: Normal Area and Production of Major Crops: (Area in 000 ha, Production in 000 Tonnes & Yield in kg/ha) Crop Scenario (2017-18 to 2021-22)
# Normal PROPN compound → Area
# Area PROPN ROOT → Area
# and CCONJ cc → Area
# Production PROPN conj → Area
# of ADP prep → Production
# Major PROPN compound → Crops
# Crops PROPN pobj → of
# : PUNCT punct → Area
# ( PUNCT punct → Area
# Area NOUN appos → Area
# in ADP prep → Area
# 000 NUM nummod → ha
# ha INTJ pobj → in
# , PUNCT punct → Area
# Production NOUN conj → Area
# in ADP prep → Production
# 000 NUM nummod → Tonnes
# Tonnes NOUN pobj → in
# & CCONJ cc → Tonnes
# Yield PROPN conj → Tonnes
# in ADP prep → Tonnes
# kg PROPN pobj → in
# / SYM punct → kg
# ha INTJ intj → in
# ) PUNCT pobj → in
# Crop PROPN compound → Scenario
# Scenario PROPN pobj → in
# ( PUNCT punct → Scenario
# 2017 NUM appos → Scenario
# - SYM punct → 18
# 18 NUM prep → 2017
# to PART prep → Production
# 2021 NUM pobj → to
# - SYM punct → to
# 22 NUM pobj → to
# ) PUNCT punct → Area
#
# SENTENCE: Crop Season Area Production Yield Rice Kharif 235.80 609.23 2584 Rabi 17.40 61.49 3534 Wheat Rabi 317.20 917.88 2894 Barley Rabi 21.80 30.22 1386 Ragi Kharif 90.80 125.55 1383 Maize Kharif 21 43.31 2062 Small Millets Kharif 52.80 72.23 1368 Kharif 164.60 241.08 1465 Total Coarse Cereals Rabi/Sum 21.80 30.22 1386 Total 186.40 271.30 1455 Kharif 400.40 850.31 2124 Total Cereals Rabi/Sum 356.40 1009.59 2833 Total 756.80 1859.90 2458 Tur Kharif 3.20 3.12 975 Urd Kharif 12.60 12.16 965
# Crop PROPN compound → Season
# Season PROPN compound → Area
# Area PROPN compound → Production
# Production PROPN compound → Yield
# Yield NOUN compound → Kharif
# Rice PROPN compound → Kharif
# Kharif PROPN nmod → Kharif
# 235.80 NUM punct → Kharif
# 609.23 NUM nummod → Rabi
# 2584 NUM nummod → Rabi
# Rabi PROPN appos → Kharif
# 17.40 NUM nummod → Rabi
# 61.49 NUM nummod → 3534
# 3534 NUM npadvmod → Rabi
# Wheat PROPN compound → Rabi
# Rabi PROPN nmod → Kharif
# 317.20 NUM nmod → Kharif
# 917.88 NUM compound → 2894
# 2894 NUM nummod → Kharif
# Barley PROPN compound → Rabi
# Rabi PROPN nmod → Kharif
# 21.80 NUM nummod → Rabi
# 30.22 NUM nummod → Rabi
# 1386 NUM nummod → Rabi
# Ragi PROPN compound → Kharif
# Kharif PROPN nmod → Kharif
# 90.80 NUM nummod → Kharif
# 125.55 NUM nummod → 1383
# 1383 NUM nummod → Kharif
# Maize PROPN compound → Kharif
# Kharif PROPN ROOT → Kharif
# 21 NUM nummod → Kharif
# 43.31 NUM nummod → 2062
# 2062 NUM appos → Kharif
# Small PROPN compound → Millets
# Millets PROPN compound → Kharif
# Kharif PROPN appos → Kharif
# 52.80 NUM nummod → Kharif
# 72.23 NUM nummod → 1368
# 1368 NUM npadvmod → 52.80
# Kharif PROPN npadvmod → Kharif
# 164.60 NUM quantmod → 1465
# 241.08 NUM compound → 1465
# 1465 NUM nummod → Kharif
# Total PROPN nmod → Total
# Coarse PROPN compound → Rabi
# Cereals PROPN nmod → Rabi
# Rabi PROPN preconj → Total
# / SYM punct → Rabi
# Sum PROPN nmod → Total
# 21.80 NUM nummod → Sum
# 30.22 NUM nummod → 1386
# 1386 NUM nummod → Sum
# Total PROPN nmod → 1455
# 186.40 NUM nummod → Total
# 271.30 NUM nummod → Total
# 1455 NUM npadvmod → Kharif
# Kharif PROPN nmod → Rabi
# 400.40 NUM nmod → 2124
# 850.31 NUM prep → 400.40
# 2124 NUM nummod → Kharif
# Total PROPN compound → Cereals
# Cereals PROPN compound → Rabi
# Rabi PROPN appos → Kharif
# / SYM punct → Rabi
# Sum PROPN appos → Rabi
# 356.40 NUM nummod → Sum
# 1009.59 NUM nummod → Sum
# 2833 NUM nummod → Sum
# Total PROPN nmod → Tur
# 756.80 NUM quantmod → 2458
# 1859.90 NUM compound → 2458
# 2458 NUM nummod → Tur
# Tur PROPN compound → Kharif
# Kharif PROPN appos → Kharif
# 3.20 NUM nummod → Kharif
# 3.12 NUM compound → 975
# 975 NUM appos → 3.20
# Urd PROPN compound → Kharif
# Kharif PROPN appos → Kharif
# 12.60 NUM nummod → 965
# 12.16 NUM nummod → 965
# 965 NUM appos → Kharif
#
# SENTENCE: [Type text] Page 6 Crop Scenario 2017-18 to 2021-22) Crop Season Area Production Yield Gram Rabi 1.00 0.78 776 Lentil Rabi 10.60 8.94 843 Pea Rabi Kharif 43.00 43.07 1002 Total Pulses Rabi/Sum 17.80 15.35 862 Total 60.80 58.42 961 Kharif 443.40 893.38 2015 Total Food Grains Rabi/Sum 374.20 1024.94 27398 Total 817.60 1918.32 2346 Groundnut Kharif 1.00 1.37 1374 Soybean Kharif 8.40 9.96 1186
# [ X nmod → text
# Type NOUN compound → text
# text NOUN dep → Rabi
# ] PUNCT punct → text
# Page NOUN nmod → Scenario
# 6 NUM nummod → Page
# Crop PROPN compound → Scenario
# Scenario PROPN appos → text
# 2017 NUM nummod → Scenario
# - SYM punct → Scenario
# 18 NUM quantmod → 2021
# to PART quantmod → 2021
# 2021 NUM appos → Scenario
# - SYM punct → 2021
# 22 NUM nummod → 2021
# ) PUNCT punct → Scenario
# Crop PROPN compound → Season
# Season PROPN compound → Area
# Area PROPN compound → Production
# Production PROPN compound → Yield
# Yield NOUN compound → Rabi
# Gram PROPN compound → Rabi
# Rabi PROPN ROOT → Rabi
# 1.00 NUM nummod → 776
# 0.78 NUM nummod → 776
# 776 NUM nummod → Rabi
# Lentil PROPN compound → Rabi
# Rabi PROPN punct → Rabi
# 10.60 NUM nummod → Rabi
# 8.94 NUM compound → 843
# 843 NUM appos → Rabi
# Pea NOUN compound → Rabi
# Rabi PROPN compound → Kharif
# Kharif PROPN npadvmod → Rabi
# 43.00 NUM quantmod → 1002
# 43.07 NUM compound → 1002
# 1002 NUM appos → Kharif
# Total PROPN compound → Pulses
# Pulses PROPN compound → Rabi
# Rabi PROPN punct → Rabi
# / SYM punct → Rabi
# Sum PROPN appos → Rabi
# 17.80 NUM nummod → Sum
# 15.35 NUM compound → 862
# 862 NUM nummod → Rabi
# Total PROPN compound → Rabi
# 60.80 NUM nummod → 961
# 58.42 NUM compound → 961
# 961 NUM nummod → Rabi
# Kharif PROPN nmod → Rabi
# 443.40 NUM nummod → Kharif
# 893.38 NUM nmod → 2015
# 2015 NUM npadvmod → 443.40
# Total PROPN compound → Rabi
# Food PROPN compound → Grains
# Grains PROPN compound → Rabi
# Rabi PROPN punct → Rabi
# / SYM punct → Rabi
# Sum PROPN appos → Rabi
# 374.20 NUM nummod → Sum
# 1024.94 NUM nummod → 27398
# 27398 NUM appos → Rabi
# Total PROPN nmod → Kharif
# 817.60 NUM nummod → Total
# 1918.32 NUM appos → Total
# 2346 NUM nummod → 1918.32
# Groundnut PROPN compound → Kharif
# Kharif PROPN punct → Rabi
# 1.00 NUM nummod → Kharif
# 1.37 NUM nummod → Kharif
# 1374 NUM nummod → Kharif
# Soybean PROPN compound → Kharif
# Kharif PROPN appos → Kharif
# 8.40 NUM nummod → Kharif
# 9.96 NUM compound → 1186
# 1186 NUM punct → Kharif
#
# SENTENCE: Sesamum Kharif 2.00 0.57 285 R&M Rabi 16.60 14.61 880 Kharif 11.40 11.90 1044 Oilseeds Rabi/Sum 16.60 14.61 880 Total 28.00 26.51 947 Sugarcane 72.60 5347.68 73660 [Type text] Page 7
# Sesamum PROPN compound → Kharif
# Kharif PROPN ROOT → Kharif
# 2.00 NUM quantmod → 285
# 0.57 NUM compound → 285
# 285 NUM nummod → Kharif
# R&M PROPN compound → Rabi
# Rabi PROPN appos → Kharif
# 16.60 NUM compound → 14.61
# 14.61 NUM appos → Rabi
# 880 NUM nummod → 14.61
# Kharif PROPN appos → Rabi
# 11.40 NUM compound → 11.90
# 11.90 NUM appos → Kharif
# 1044 NUM appos → Kharif
# Oilseeds PROPN compound → Rabi
# Rabi PROPN appos → Kharif
# / SYM punct → Rabi
# Sum PROPN nmod → Total
# 16.60 NUM nummod → Sum
# 14.61 NUM nummod → Sum
# 880 NUM nummod → 14.61
# Total PROPN npadvmod → Kharif
# 28.00 NUM nummod → 947
# 26.51 NUM compound → 947
# 947 NUM nummod → Total
# Sugarcane PROPN appos → Kharif
# 72.60 NUM nummod → 73660
# 5347.68 NUM nummod → 73660
# 73660 NUM appos → Sugarcane
# [ X nmod → text
# Type NOUN compound → text
# text NOUN appos → Kharif
# ] PUNCT punct → text
# Page NOUN appos → Kharif
# 7 NUM nummod → Page

# %% [markdown]
# **Step 6: Dependency Parsing**
#
# You extracted:
#
# - Syntactic heads
#
# - Dependency labels
#
# - Sentence roots
